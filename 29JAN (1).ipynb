# %% [markdown]
# 29JAN_Assignment
#
#
# Who developed the python programming language?
#
# The Python programming language was developed by Guido van Rossum in the late 1980s and early 1990s. Van Rossum is a Dutch programmer and software developer who started the project to create Python as a hobby project, with the goal of creating an easy-to-use and powerful scripting language. Python was first released in 1991 and has since become one of the most widely used programming languages in the world, with a large and active community of developers and users.
#
#
# Which type of programming does python support?
#
# Python supports multiple programming paradigms, including:
#
# Object-Oriented Programming (OOP): Python has full support for object-oriented programming, allowing developers to create classes, objects, and inherit properties and methods.
#
# Functional Programming: Python supports functional programming concepts such as first-class functions, closures, and higher-order functions.
#
# Procedural Programming: Python also supports procedural programming, where the focus is on writing procedures or functions that operate on data.
#
# Imperative Programming: Python has support for imperative programming, where the emphasis is on how the program operates and changes a system's state.
#
#
# Is python case sensitive when dealing with identifies?
#
# Yes, Python is case-sensitive when dealing with identifiers, such as variables, functions, and class names.
#
# What is the correct extension of the python file?
#
# The correct extension for a Python file is .py.
# Note: There are also other file extensions used for Python, such as .pyc and .pyo, which are compiled bytecode files, but they are usually not created or used directly by developers.
#
# 5.Is python code compiled or interpreted?
#
# Python is an interpreted language, not a compiled language. This means that the code is executed line by line, rather than being compiled into machine-executable code prior to execution.
#
# 6. Name a few blocks of code that are used to define in python language.
#
# In Python, there are several blocks of code used to define code blocks and control structures, including:
# Functions: defined using the "def" keyword and contain a block of code that can be called and executed later.
#
# Classes: defined using the "class" keyword and represent objects and their methods in object-oriented programming.
#
# Conditional statements: used to execute a block of code based on whether a condition is True or False, such as "if" and "if-else" statements.
#
# Loops: used to repeat a block of code multiple times, such as "for" and "while" loops.
#
# Try-except blocks: used to handle exceptions and errors that may occur in your code.
#
# These blocks of code are used to structure the logic and flow of your code, allowing you to write clear and readable code that can be easily understood and maintained.
#
# 7.State a character used to give a single line comment in python.
#
# In Python, the character "#" is used to give a single line comment.
#
# 8. Mention functions which can help us to find which version of python we are working on.
#
# In Python, you can use the following functions to find the version of Python you are working on:
#
# sys.version: returns a string containing information about the Python version, including the version number, build number, and compiler.
#
# sys.version_info: returns a named tuple containing information about the Python version, including the major, minor, and micro version numbers.
#
# platform.python_version(): returns a string containing the version number of the Python interpreter.
#
# 9.  Python supports the creation of anonymous functions at runtime, using a construct called
# "lambda" functions.
#
# 10. What does pip stand for python?
#
# PIP stands for "Pip Installs Packages"
#
# 11.  Mention a few built-in functions in python?
#
# print(): used to print output to the console
# len(): used to get the length of a list, string, or other iterable object
# int(): used to convert a value to an integer
# float(): used to convert a value to a floating-point number
# str(): used to convert a value to a string
# max(): used to find the maximum value in a list or other iterable object
# min(): used to find the minimum value in a list or other iterable object
# sum(): used to calculate the sum of a list or other iterable object
# sorted(): used to sort a list or other iterable object
# abs(): used to get the absolute value of a number
#
# 12. What is the maximum possible length of an identifier in Python?
#
# 79 characters
# 13.  What are the benefits of using Python?
#
# Easy to Learn and Use: Python has a simple and easy-to-read syntax, making it a great choice for beginners. It is also relatively easy to write, debug, and maintain, making it accessible to a wider range of users.
#
# Versatile: Python can be used for a wide range of applications, including web development, scientific computing, data analysis, artificial intelligence, and more. It also supports multiple programming paradigms, including procedural, object-oriented, and functional programming.
#
# Large Standard Library: Python has a large and comprehensive standard library, which provides tools and modules for common programming tasks such as reading and writing files, connecting to the web, and working with data. This saves time and effort, as developers don't need to write everything from scratch.
#
# Open-Source: Python is open-source software, meaning it is free to use, distribute, and modify. This has led to a thriving community of users and contributors, who have created many libraries and tools that can be used with Python.
#
# Large Community: Python has a large and active community of users, making it easy to find help, support, and resources. This community also helps to maintain and improve the language, ensuring that it remains relevant and up-to-date.
#
# Good Performance: Python is known for its good performance, especially for tasks that involve data processing, text manipulation, and scientific computing. Additionally, Python can be used with other high-performance programming languages, such as C or Fortran, to build high-performance applications.
#
# 14. How is memory managed in Python?
#
# The Python memory manager manages the memory used by Python objects, allocating and freeing memory as needed. This means that you do not need to worry about managing memory yourself, as the memory manager will automatically allocate and deallocate memory as objects are created and destroyed.
#
# 15. How to install Python on Windows and set path variables?
#
# Here are the steps to install Python on Windows and set the PATH variables:
#
# Download the Python installer: Go to the official Python website (https://www.python.org/) and download the latest version of Python for Windows.
#
# Run the installer: Double-click on the downloaded file and follow the on-screen instructions to install Python. Make sure to select the option to add Python to the PATH during the installation process.
#
# Verify the installation: Open a Command Prompt window and type python to verify that the installation was successful. If the installation was successful, you should see the Python prompt >>>.
#
# Set the PATH variable: To set the PATH variable, follow these steps:
# a. Open the Start menu and search for "Environment Variables".
# b. Click on "Edit the system environment variables".
# c. Click on the "Environment Variables" button.
# d. Under "System Variables", scroll down and find the "Path" variable.
# e. Click on "Edit" and then "New".
# f. Add the path to the Python executable, which is typically C:\PythonXX\python.exe (where XX is the version number).
#
# Test the PATH variable: Close and reopen the Command Prompt window, then type python again to verify that the PATH variable is set correctly.
#
# These steps should allow you to install Python on Windows and set the PATH variable, allowing you to run Python from anywhere on your system. Note that these steps may vary slightly depending on your version of Windows.
#
# 16. Is indentation required in python?
#
# Indentation is mandatory in python to define the blocks of statements. The number of spaces must be uniform in a block of code. It is preferred to use whitespaces instead of tabs to indent in python
